# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils import *

# %%
data = pd.read_csv('dataset/reviews.csv')

# %%
classes = np.unique(data["sentiment"])
dist = []
distribution = {}
for c in classes:
    dist.append((np.count_nonzero(data["sentiment"] == c)/len(data)).round(4)*100)
    distribution[c] = (np.count_nonzero(data["sentiment"] == c)/len(data)).round(4)*100
